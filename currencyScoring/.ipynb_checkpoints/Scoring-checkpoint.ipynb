# %%
import pandas as pd
import numpy as np
import math
import datetime
import matplotlib.pyplot as plt

#reading the excel data to create final pandas dataframe column
def finalDFColumnName(df):
    countries = list(df.columns.values)
    pickElem = np.arange(7, len(countries), 5)
    dfColumn = ['Date', 'UK']
    for i in range(len(pickElem)):
        dfColumn.append(countries[pickElem[i]])
    return dfColumn

#function for current account scoring
def currentAccountScore(value):
    sign = value/abs(value)
    score = (abs(value) - 1) * 4 * sign * 2
    return score

#function for Real Rate scoring
def realRateScore(value):
    siVal = value - 1
    score = siVal * 4 * 2
    return score

#function for Real Effective Exchange Rate scoring
def reerScore(value):
    if( value > 120):
        score = -1 * (value - 110)
        return score * 2
    elif (value < 90) :
        score  = 90 - value
        return score * 2
    return 0
        
#function for creating currency score and getting fx rates
def createScoreQuarter(currencyScore, fxRates, dfList, dfColumn):
    #df['Score'] = df.apply(currentAccountScore, axis=1)
    #df['Score'] = df['Score'] + df.apply(realRateScore, axis=1)
    listAddScore = []
    listFxRate = []
    listAddScore.append(datetime.datetime.strftime(dfList[0],'%Y-%m'))
    listFxRate.append(datetime.datetime.strftime(dfList[0],'%Y-%m'))
    pickElem = np.arange(2, len(dfList), 5)
    for i in range(len(pickElem)):
        score = currentAccountScore(dfList[pickElem[i]])
        score = score + realRateScore(dfList[pickElem[i] + 1])
        score = score + reerScore(dfList[pickElem[i] + 2])
        listAddScore.append(score)
        listFxRate.append(dfList[pickElem[i] + 3])
    currencyScore = currencyScore.append(pd.DataFrame([listAddScore],columns = dfColumn))
    fxRates = fxRates.append(pd.DataFrame([listFxRate],columns = dfColumn))
    return currencyScore, fxRates

def printTrades(changeArr, dfColumn, arr, laterRate, quarter):
    columnName = dfColumn[1:len(dfColumn)]
    indMin = np.argpartition(arr, 5)[:5]
    indMax = np.argpartition(arr, -5)[-5:]
    tradeProfit = 0
    print("New Quarter : " + quarter)
    for i in range(len(indMin)):
        if( -10 >= arr[indMin[i]] >= -20):
            print("Short Currency : ->" + columnName[indMin[i]])    
            tradeProfit = tradeProfit - changeArr[indMin[i]] * (1/laterRate[indMin[i]]) 
        elif( -25>= arr[indMin[i]] >= -65):
            print("Long Currency : ->" + columnName[indMin[i]])    
            tradeProfit = tradeProfit + changeArr[indMin[i]] * (1/laterRate[indMin[i]]) 
   
    for i in range(len(indMax)):
        if(50<= arr[indMax[i]] <= 65):
            print("Long Currency : ->" + columnName[indMax[i]])
            tradeProfit = tradeProfit + changeArr[indMax[i]] * (1/laterRate[indMax[i]])
        elif (80 <= arr[indMax[i]] <= 100):
            print("Short Currency : ->" + columnName[indMax[i]])
            tradeProfit = tradeProfit - changeArr[indMax[i]] * (1/laterRate[indMax[i]])
        
    print("The profit for trade this Quarter " + str(tradeProfit)) 
    print("-------------------------------")
    return tradeProfit

def plotFunction(dateQuarter, tradeRetQuarter, string):
    plt.plot(dateQuarter, tradeRetQuarter)
    plt.ylabel('Profit/Loss per Quarter ' + string)
    plt.xlabel('Quarters')
    plt.xticks(rotation=90)
    plt.show()
        
        
if __name__=='__main__':
    df = pd.read_excel('data/Currency_Project_Final.xlsx')
    
    flip = False
    dfColumn = finalDFColumnName(df)
    currencyScore = pd.DataFrame(columns = dfColumn)
    fxRates = pd.DataFrame(columns = dfColumn)
    
    #create simple dataframes from the excel for furthur analysis
    for row in df.iterrows():
        if(flip == False):
            flip = True
        else:
            index, data = row
            dataList = data.tolist()

            #running per quarter-- remove condition if monthly data present
            if(math.isnan(dataList[2])):
                continue
            else:
                currencyScore, fxRates = createScoreQuarter(currencyScore, fxRates, dataList, dfColumn)
    print(currencyScore)
    rownum = 0 
    totalQuat = []
    quarter = []
    dateQuarter = currencyScore.iloc[:, 0].values.tolist()[1:len(currencyScore.iloc[:, 0].values.tolist())]
    for row in currencyScore.iterrows():
        if(rownum < len(currencyScore.index)-1):
            currRate = fxRates.iloc[rownum].values.tolist()
            quarter = currRate [0]
            currRate  = currRate [1: len(currRate )]
            laterRate = fxRates.iloc[rownum + 1].values.tolist()
            laterRate = laterRate[1:len(laterRate)]
            changeArr = []
            currScore = currencyScore.iloc[rownum]
            currScore = currScore[1:len(currScore)]
            for index in range(len(laterRate)):
                changeArr.append(laterRate[index] - currRate[index] )
            index, data = row
            totalQuat.append(printTrades(changeArr, dfColumn, currScore , laterRate, quarter))
            rownum  =  rownum +  1

    print("Positions 1 USD either Long/Short for each quarter in respective currency trade")
    print("Trade Values in absolute terms "+ str(totalQuat))
    print( "Percentage Success: " , np.sum(np.array(totalQuat) > 0, axis=0)/ len(totalQuat) *100  )
    
    #plot of gross profit per quarter
    plotFunction(dateQuarter, totalQuat, "Total Profit/Loss Absolute Terms USD")
# Out:
#       Date         UK      Japan      Korea  South Africa    Germany  \
# 0  2010-01   9.235432  26.469240  33.691414     49.915872  55.282984
# 0  2010-04   9.239464  23.432256  59.204360     57.447864  52.130488
# 0  2010-07  -3.986936  22.773864  56.056600     58.704056  47.140392
# 0  2010-10  -5.032808  23.730136  26.108200     63.363749  51.806728
# 0  2011-01  15.946928  18.845888  24.661612     50.139560  60.400544
# 0  2011-04  24.288753   6.588128  29.927871     56.177728  55.397328
# 0  2011-07   2.585376   9.022616  44.355176     49.633624  54.359272
# 0  2011-10   1.231680   4.571472  40.443576     46.889392  50.355480
# 0  2012-01  -4.556696   2.522976  28.148312     31.609072  58.623656
# 0  2012-04 -17.331680  -0.391880  42.428456     24.375272  52.879384
# 0  2012-07 -14.398752  -4.940849  44.673488     18.891848  50.497432
# 0  2012-10 -22.183872  -1.674368  64.041760     20.308840  47.744696
# 0  2013-01 -22.339584   2.699909  54.918432     20.977792  44.914528
# 0  2013-04 -17.635776  24.711592  58.057488     10.831528  53.701040
# 0  2013-07 -22.804232  19.128318  62.630944     31.122768  45.363408
# 0  2013-10 -29.599256  12.802645  61.602528     44.064216  55.073056
# 0  2014-01 -12.928448  29.536810  54.477352     56.756136  57.155024
# 0  2014-04 -11.214504  21.499462  62.156408     45.164448  50.591712
# 0  2014-07 -17.919888  18.388860  51.807912     58.181032  54.731152
# 0  2014-10 -30.452920  37.317096  63.018808     48.444776  52.482728
# 0  2015-01 -29.572208  47.225048  67.310352     44.271208  54.818504
# 0  2015-04 -14.224272  51.410848  58.324720     58.922616  56.099632
# 0  2015-07 -15.744208  52.907680  67.034136     57.658568  65.670528
# 0  2015-10 -39.086752  51.693936  61.544176     49.959816  58.416136
# 0  2016-01 -29.529312  46.717216  72.099576     94.660968  52.049040
# -------------------------------
# New Quarter : 2010-10
# Long Currency : ->Germany
# Long Currency : ->Sweden
# Long Currency : ->Denmark
# Long Currency : ->South Africa
# Short Currency : ->Norway
# The profit for trade this Quarter0.0478207412866
# -------------------------------
# New Quarter : 2011-01
# Long Currency : ->South Africa
# Long Currency : ->Sweden
# Long Currency : ->Germany
# Short Currency : ->Norway
# The profit for trade this Quarter-0.107043011101
# -------------------------------
# New Quarter : 2011-04
# Long Currency : ->Sweden
# Long Currency : ->Germany
# Long Currency : ->South Africa
# Long Currency : ->Denmark
# The profit for trade this Quarter0.0933880800533
# -------------------------------
# New Quarter : 2011-07
# Long Currency : ->Germany
# Long Currency : ->Denmark
# Long Currency : ->Sweden
# The profit for trade this Quarter0.0916879814525
# -------------------------------
# New Quarter : 2011-10
# Long Currency : ->Germany
# Long Currency : ->Denmark
# The profit for trade this Quarter0.117501768403
# -------------------------------
# New Quarter : 2012-01
# Short Currency : ->Finland
# Long Currency : ->Germany
# The profit for trade this Quarter0.0169167078221
# -------------------------------
# New Quarter : 2012-04
# Long Currency : ->Iceland
# Short Currency : ->UK
# Short Currency : ->Canada
# Long Currency : ->Germany
# Long Currency : ->Denmark
# Short Currency : ->Norway
# The profit for trade this Quarter0.0733918266498
# -------------------------------
# New Quarter : 2012-07
# Short Currency : ->Canada
# Short Currency : ->UK
# Short Currency : ->Australia
# Long Currency : ->Germany
# Long Currency : ->Iceland
# Short Currency : ->Norway
# The profit for trade this Quarter0.0171122139593
# -------------------------------
# New Quarter : 2012-10
# Short Currency : ->Canada
# Short Currency : ->Australia
# Long Currency : ->Korea
# Short Currency : ->Norway
# The profit for trade this Quarter0.0908985288613
# -------------------------------
# New Quarter : 2013-01
# Short Currency : ->Canada
# Long Currency : ->Denmark
# Long Currency : ->Korea
# Short Currency : ->Norway
# The profit for trade this Quarter-0.0441932352854
# -------------------------------
# New Quarter : 2013-04
# Short Currency : ->UK
# Short Currency : ->Canada
# Long Currency : ->Germany
# Long Currency : ->Korea
# Long Currency : ->Denmark
# Short Currency : ->Norway
# The profit for trade this Quarter-0.137237680117
# -------------------------------
# New Quarter : 2013-07
# Short Currency : ->Finland
# Long Currency : ->Korea
# Long Currency : ->Denmark
# Short Currency : ->Norway
# Short Currency : ->Iceland
# The profit for trade this Quarter0.0285071002591
# -------------------------------
# New Quarter : 2013-10
# Long Currency : ->UK
# Long Currency : ->Germany
# Long Currency : ->Korea
# Long Currency : ->Denmark
# Short Currency : ->Norway
# Short Currency : ->Iceland
# The profit for trade this Quarter-0.0370572297902
# -------------------------------
# New Quarter : 2014-01
# Short Currency : ->UK
# Long Currency : ->Korea
# Long Currency : ->South Africa
# Long Currency : ->Germany
# Long Currency : ->Denmark
# The profit for trade this Quarter-0.083087723231
# -------------------------------
# New Quarter : 2014-04
# Short Currency : ->UK
# Long Currency : ->Iceland
# Long Currency : ->Israel
# Long Currency : ->Denmark
# Long Currency : ->Korea
# Short Currency : ->Norway
# The profit for trade this Quarter0.0531843894099
# -------------------------------
# New Quarter : 2014-07
# Short Currency : ->UK
# Short Currency : ->Finland
# Long Currency : ->Germany
# Long Currency : ->South Africa
# Long Currency : ->Iceland
# Short Currency : ->Norway
# The profit for trade this Quarter0.021336576052
# -------------------------------
# New Quarter : 2014-10
# Long Currency : ->UK
# Long Currency : ->Germany
# Long Currency : ->Korea
# The profit for trade this Quarter0.0890894346885
# -------------------------------
# New Quarter : 2015-01
# Long Currency : ->UK
# Short Currency : ->Belgium
# Short Currency : ->Canada
# Short Currency : ->France
# Long Currency : ->Germany
# The profit for trade this Quarter-0.166378474134
# -------------------------------
# New Quarter : 2015-04
# Short Currency : ->UK
# Short Currency : ->France
# Long Currency : ->Germany
# Long Currency : ->Korea
# Long Currency : ->South Africa
# Short Currency : ->Iceland
# The profit for trade this Quarter0.131540880887
# -------------------------------
# New Quarter : 2015-07
# Short Currency : ->UK
# Short Currency : ->Australia
# Long Currency : ->Iceland
# The profit for trade this Quarter-0.103844976099
# -------------------------------
# New Quarter : 2015-10
# Long Currency : ->UK
# Short Currency : ->Australia
# Long Currency : ->Japan
# Long Currency : ->Iceland
# Long Currency : ->Germany
# Long Currency : ->Norway
# Long Currency : ->Korea
# The profit for trade this Quarter0.0403078589929
# -------------------------------
# New Quarter : 2016-01
# Long Currency : ->UK
# Long Currency : ->Germany
# Short Currency : ->South Africa
# The profit for trade this Quarter0.123742663565
# -------------------------------
# New Quarter : 2016-04
# Long Currency : ->UK
# Short Currency : ->Australia
# Long Currency : ->Korea
# Long Currency : ->Iceland
# Short Currency : ->South Africa
# The profit for trade this Quarter0.0315837992037
# -------------------------------
# New Quarter : 2016-07
# Long Currency : ->UK
# Short Currency : ->Australia
# Long Currency : ->Iceland
# Short Currency : ->South Africa
# The profit for trade this Quarter0.0377436872706
# -------------------------------
# New Quarter : 2016-10
# Long Currency : ->Denmark
# Long Currency : ->Iceland
# Long Currency : ->Norway
# Short Currency : ->South Africa
# The profit for trade this Quarter0.100745421749
# -------------------------------
# New Quarter : 2017-01
# Short Currency : ->UK
# Long Currency : ->Korea
# Long Currency : ->Germany
# Long Currency : ->Denmark
# The profit for trade this Quarter-0.00839092414702
# -------------------------------
# New Quarter : 2017-04
# Long Currency : ->UK
# Short Currency : ->Finland
# Long Currency : ->Denmark
# Long Currency : ->Norway
# The profit for trade this Quarter-0.0414438863039
# -------------------------------
# New Quarter : 2017-07
# Long Currency : ->Iceland
# Long Currency : ->Germany
# The profit for trade this Quarter0.0168178213833
# -------------------------------
# New Quarter : 2017-10
# Short Currency : ->UK
# Short Currency : ->Iceland
# Long Currency : ->Japan
# Short Currency : ->South Africa
# The profit for trade this Quarter0.1475893665
# -------------------------------
# Positions 1 USD either Long/Short for each quarter in respective currency trade
# Trade Values in absolute terms [0.11284340672794432, -0.037119044237475654, -0.11652984605118466, 0.047820741286566049, -0.10704301110100589, 0.093388080053284361, 0.091687981452472631, 0.11750176840327285, 0.016916707822142888, 0.073391826649820718, 0.017112213959283203, 0.090898528861297775, -0.044193235285378475, -0.13723768011726209, 0.028507100259079668, -0.037057229790191187, -0.083087723231008659, 0.053184389409876152, 0.021336576051987181, 0.089089434688503472, -0.16637847413415185, 0.13154088088717608, -0.1038449760986845, 0.040307858992932426, 0.12374266356538893, 0.031583799203689381, 0.037743687270585503, 0.10074542174883731, -0.0083909241470177288, -0.041443886303942586, 0.016817821383314606, 0.14758936649963944]
# Percentage Success:  65.625
